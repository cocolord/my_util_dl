# %%
# !unzip "/content/drive/My Drive/dataset_918/dataset2014.zip" -d "/content/drive/My Drive/dataset_918/cd2014_new"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003975.jpg
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003976.jpg
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003977.jpg
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003978.jpg
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003979.jpg
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003980.jpg
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003981.jpg
#   inflating: /content/drive/My Drive/dataset_918/cd2014_new/dataset/turbulence/turbulence2/input/in003982.jpg
# ...

# %%
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8d3a3a7c8b5f> in <module>()
#       5
#       6 zip_ref = zipfile.ZipFile("/content/drive/My Drive/dataset_918/dataset2014.zip", 'r')
# ----> 7 zip_ref.extractall("/content/drive/My Drive/dataset_918/dataset2014")
#       8 zip_ref.close()
#
# /usr/lib/python3.6/zipfile.py in extractall(self, path, members, pwd)
#    1522
#    1523         for zipinfo in members:
# -> 1524             self._extract_member(zipinfo, path, pwd)
#    1525
#    1526     @classmethod
#
# /usr/lib/python3.6/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1576
#    1577         with self.open(member, pwd=pwd) as source, \
# -> 1578              open(targetpath, "wb") as target:
# ...
